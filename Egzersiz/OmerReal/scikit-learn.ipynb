# %%
from sklearn.impute import SimpleImputer
from sklearn.experimental import  enable_iterative_imputer
from sklearn.preprocessing import LabelEncoder
import pandas as pd
df=pd.read_csv("/workspace/DeepLearningFundamentals/Dokumanlar/01_Preprocessing/data/sample.csv")

# %%
dfOrn = df.copy()
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit_transform(dfOrn)
dfOrnClean = pd.DataFrame(data=imputer.fit_transform(dfOrn))
dfOrnClean
# Out:
#             0      1        2     3  4
# 0   İngiltere  Kadın  20000.0  32.0  1
# 1   İngiltere  Erkek  15000.0  32.0  2
# 2   İngiltere  Erkek  23000.0  32.0  3
# 3     Turkiye  Kadın  20000.0  45.0  1
# 4      Fransa  Erkek  15000.0  23.0  2
# 5   İngiltere  Erkek  23000.0  12.0  3
# 6     Almanya  Kadın  20000.0  45.0  1
# 7     Turkiye  Erkek  18000.0  32.0  2
# 8   İngiltere  Erkek  23000.0  12.0  3
# 9     Almanya  Kadın  22000.0  45.0  1
# 10  Avusturya  Kadın  15000.0  46.0  2
# 11  İngiltere  Erkek  23000.0  32.0  3
# 12    İspanya  Erkek  22000.0  32.0  1
# 13  İngiltere  Erkek  22000.0  32.0  1
# 14    İspanya  Erkek  22000.0  32.0  1
# 15  İngiltere  Erkek  22000.0  45.0  1

# %%
dfOrn = df.copy()
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit_transform(dfOrn[:,("Ulke","Cinsiyet")])
dfOrnTemiz = pd.DataFrame(data=imputer.fit_transform(dfOrn.loc[:,("Ulke","Cinsiyet")]))
dfOrn["Ulke"] = dfOrnTemiz[0]
dfOrn["Cinsiyet"] = dfOrnTemiz[1]
dfOrn.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/_libs/index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), ('Ulke', 'Cinsiyet'))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 dfOrn = df.copy()
#       2 imputer = SimpleImputer(strategy='most_frequent')
# ----> 3 imputer.fit_transform(dfOrn[:,("Ulke","Cinsiyet")])
#       4 dfOrnTemiz = pd.DataFrame(data=imputer.fit_transform(dfOrn.loc[:,("Ulke","Cinsiyet")]))
#       5 dfOrn["Ulke"] = dfOrnTemiz[0]
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/indexes/base.py:3660, in Index.get_loc(self, key)
#    3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
# -> 3660     self._check_indexing_error(key)
#    3661     raise
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/indexes/base.py:5737, in Index._check_indexing_error(self, key)
#    5733 def _check_indexing_error(self, key):
#    5734     if not is_scalar(key):
#    5735         # if key is not a scalar, directly raise an error (the code below
#    5736         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5737         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), ('Ulke', 'Cinsiyet'))
