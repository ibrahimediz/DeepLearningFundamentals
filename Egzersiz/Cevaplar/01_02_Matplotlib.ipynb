# %% [markdown]
# beginner_datasets/heart.csv
# 1. yukarıdaki adreste yer alan veri setini yükleyiniz
# 2. seaborn kütüphanesini import ediniz
# 3. AGE_50,MD_50,CHOL_50,CHOL_62,DEATH sütunlarını kullanarak
# bir pairplot grafiği çiziniz,renk için DEATH sütununu kullanınız.

# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("/workspace/DeepLearningFundamentals/beginner_datasets/heart.csv")
sns.pairplot(data=df[["AGE_50","MD_50","CHOL_50","CHOL_62","DEATH"]],hue="DEATH",markers="x")
