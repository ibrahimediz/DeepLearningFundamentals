# %%
import pandas as pd
import numpy as np

# %%
read=pd.read_csv("/workspace/DeepLearningFundamentals/Datasets/diabetes.csv")

read
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
read.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
# 5            0      137             40             35      168  43.1
# 6            5      116             74              0        0  25.6
# 7            3       78             50             32       88  31.0
# 8           10      115              0              0        0  35.3
# 9            2      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.627   50        1
# 2                     0.351   31        0
# ...

# %%
read.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 759            1      106             76              0        0  37.5
# 760            6      190             92              0        0  35.5
# 761            2       88             58             26       16  28.4
# 762            9      170             74             31        0  44.0
# 763            9       89             62              0        0  22.5
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 759                     0.197   26        0
# 760                     0.278   66        1
# 761                     0.766   22        0
# ...

# %%
# Out:
# array([1, 2, 3, 4, 5])

# %%
read.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
read.shape
# Out:
# (769, 9)

# %%
read.values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
read.Age
# Out:
# 0      50
# 1      50
# 2      31
# 3      32
# 4      21
#        ..
# 764    63
# 765    27
# 766    30
# 767    47
# 768    23
# Name: Age, Length: 769, dtype: int64

# %%
age=read.Age

# %%
index=age.reset_index().reset_index()

# %%
index
# Out:
#      level_0  index  Age
# 0          0      0   50
# 1          1      1   50
# 2          2      2   31
# 3          3      3   32
# 4          4      4   21
# ..       ...    ...  ...
# 764      764    764   63
# 765      765    765   27
# 766      766    766   30
# 767      767    767   47
# 768      768    768   23
#
# [769 rows x 3 columns]

# %%
read.Age
# Out:
# 0      50
# 1      50
# 2      31
# 3      32
# 4      21
#        ..
# 764    63
# 765    27
# 766    30
# 767    47
# 768    23
# Name: Age, Length: 769, dtype: int64

# %%
read["BMIsQL" ]=read["BMI"].apply(lambda x:x**2)

# %%
read.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome   BMIsQL
# 0                     0.627   50        1  1128.96
# 1                     0.627   50        1  1128.96
# 2                     0.351   31        0   707.56
# 3                     0.672   32        1   542.89
# 4                     0.167   21        0   789.61

# %%
 *median
 *mean 
 *mode 
 *quantile
 *var 
 *std 
 *min 
 *max 
 *agg
# Out:
#   Cell In[47], line 1
#     *median
#     ^
# SyntaxError: can't use starred expression here

# %%
read.median()
# Out:
# Pregnancies                    3.000
# Glucose                      117.000
# BloodPressure                 72.000
# SkinThickness                 23.000
# Insulin                       29.000
# BMI                           32.000
# DiabetesPedigreeFunction       0.374
# Age                           29.000
# Outcome                        0.000
# BMIsQL                      1024.000
# dtype: float64

# %%
read.short_values("Age").iloc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2396/228200698.py in ?()
# ----> 1 read.short_values("Age").iloc()
#
# /workspace/DeepLearningFundamentals/env/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'short_values'
