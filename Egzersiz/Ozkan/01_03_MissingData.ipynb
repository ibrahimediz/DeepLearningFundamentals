# %%
import pandas as pd

# %%
df = pd.read_csv("/workspace/DeepLearningFundamentals/Dokumanlar/01_Preprocessing/data/sample.csv")
df.head()
# Out:
#         Ulke Cinsiyet    Gelir   Yas  MemTip
# 0        NaN    Kadın  20000.0   NaN       1
# 1        NaN    Erkek  15000.0  32.0       2
# 2  İngiltere      NaN  23000.0   NaN       3
# 3    Turkiye    Kadın  20000.0  45.0       1
# 4     Fransa    Erkek  15000.0  23.0       2

# %%
df.isna().sum()
# Out:
# Ulke        5
# Cinsiyet    4
# Gelir       1
# Yas         4
# MemTip      0
# dtype: int64

# %%
df2 = df.copy()
df2.dropna(axis=1) # sütun silme
# Out:
#     MemTip
# 0        1
# 1        2
# 2        3
# 3        1
# 4        2
# 5        3
# 6        1
# 7        2
# 8        3
# 9        1
# 10       2
# 11       3
# 12       1
# 13       1
# 14       1
# 15       1

# %%
df2 = df.copy()
df2.dropna(axis=0) # satır silme
# Out:
#          Ulke Cinsiyet    Gelir   Yas  MemTip
# 3     Turkiye    Kadın  20000.0  45.0       1
# 4      Fransa    Erkek  15000.0  23.0       2
# 6     Almanya    Kadın  20000.0  45.0       1
# 10  Avusturya    Kadın  15000.0  46.0       2
# 12    İspanya    Erkek  22000.0  32.0       1
# 14    İspanya    Erkek  22000.0  32.0       1

# %%
veri1 = pd.read_json("/workspace/DeepLearningFundamentals/hiking.json")
veri1.head()
# Out:
#   Prop_ID                     Name  \
# 0    B057  Salt Marsh Nature Trail
# 1    B073                Lullwater
# 2    B073                  Midwood
# 3    B073                Peninsula
# 4    B073                Waterfall
#
#                                             Location      Park_Name  \
# 0  Enter behind the Salt Marsh Nature Center, loc...    Marine Park
# 1  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
# 2  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
# 3  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
# 4  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
#
#        Length Difficulty                                      Other_Details  \
# 0   0.8 miles       None  <p>The first half of this mile-long trail foll...
# 1    1.0 mile       Easy  Explore the Lullwater to see how nature thrive...
# 2  0.75 miles       Easy  Step back in time with a walk through Brooklyn...
# 3   0.5 miles       Easy  Discover how the Peninsula has changed over th...
# 4   0.5 miles       Easy  Trace the source of the Lake on the Waterfall ...
#
#   Accessible Limited_Access  lat  lon
# 0          Y              N  NaN  NaN
# 1          N              N  NaN  NaN
# 2          N              N  NaN  NaN
# 3          N              N  NaN  NaN
# 4          N              N  NaN  NaN

# %%
veri1.isna().sum()
# Out:
# Prop_ID            0
# Name               0
# Location           0
# Park_Name          0
# Length             4
# Difficulty         6
# Other_Details      2
# Accessible         0
# Limited_Access     0
# lat               33
# lon               33
# dtype: int64

# %%
veri2 = veri1.copy()
veri2.dropna(axis=1).head() # sütun silme
# Out:
#   Prop_ID                     Name  \
# 0    B057  Salt Marsh Nature Trail
# 1    B073                Lullwater
# 2    B073                  Midwood
# 3    B073                Peninsula
# 4    B073                Waterfall
#
#                                             Location      Park_Name  \
# 0  Enter behind the Salt Marsh Nature Center, loc...    Marine Park
# 1  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
# 2  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
# 3  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
# 4  Enter Park at Lincoln Road and Ocean Avenue en...  Prospect Park
#
#   Accessible Limited_Access
# 0          Y              N
# 1          N              N
# 2          N              N
# 3          N              N
# 4          N              N

# %%
# %pip install scikit_learn
# Out:
# Requirement already satisfied: scikit_learn in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages (from scikit_learn) (1.25.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from scikit_learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from scikit_learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from scikit_learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.impute import SimpleImputer
dfOrn = df.copy()
imputer = SimpleImputer(strategy="most_frequent")
imputer.fit_transform(dfOrn.loc[:,("Ulke","Cinsiyet")])
dfOrnTemiz = pd.DataFrame(data=imputer.fit_transform(dfOrn.loc[:,("Ulke","Cinsiyet")]))
dfOrn["Ulke"]=dfOrnTemiz[0]
dfOrn["Cinsiyet"]=dfOrnTemiz[1]

# %%
dfOrn.head()
# Out:
#         Ulke Cinsiyet    Gelir   Yas  MemTip
# 0  İngiltere    Kadın  20000.0   NaN       1
# 1  İngiltere    Erkek  15000.0  32.0       2
# 2  İngiltere    Erkek  23000.0   NaN       3
# 3    Turkiye    Kadın  20000.0  45.0       1
# 4     Fransa    Erkek  15000.0  23.0       2

# %%
dfIter = dfOrn.copy()

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(dfIter["Ulke"])
dfIter["EnUlke"] = le.transform(dfIter["Ulke"])
le.fit(dfIter["Cinsiyet"])
dfIter["EnCinsiyet"] = le.transform(dfIter["Cinsiyet"])
dfIter
# Out:
#          Ulke Cinsiyet    Gelir   Yas  MemTip  EnUlke  EnCinsiyet
# 0   İngiltere    Kadın  20000.0   NaN       1       4           1
# 1   İngiltere    Erkek  15000.0  32.0       2       4           0
# 2   İngiltere    Erkek  23000.0   NaN       3       4           0
# 3     Turkiye    Kadın  20000.0  45.0       1       3           1
# 4      Fransa    Erkek  15000.0  23.0       2       2           0
# 5   İngiltere    Erkek  23000.0  12.0       3       4           0
# 6     Almanya    Kadın  20000.0  45.0       1       0           1
# 7     Turkiye    Erkek  18000.0   NaN       2       3           0
# 8   İngiltere    Erkek  23000.0  12.0       3       4           0
# 9     Almanya    Kadın      NaN  45.0       1       0           1
# 10  Avusturya    Kadın  15000.0  46.0       2       1           1
# 11  İngiltere    Erkek  23000.0   NaN       3       4           0
# 12    İspanya    Erkek  22000.0  32.0       1       5           0
# 13  İngiltere    Erkek  22000.0  32.0       1       4           0
# 14    İspanya    Erkek  22000.0  32.0       1       5           0
# 15  İngiltere    Erkek  22000.0  45.0       1       4           0

# %%
itr_Imp = IterativeImputer()
itr_Imp.fit_transform(dfIter[["EnUlke","EnCinsiyet","Yas","Gelir"]])
sonuc = pd.DataFrame(data=itr_Imp.fit_transform(dfIter[["EnUlke","EnCinsiyet","Yas","Gelir"]]))
sonuc
# Out:
#       0    1          2             3
# 0   4.0  1.0  33.365184  20000.000000
# 1   4.0  0.0  32.000000  15000.000000
# 2   4.0  0.0  31.049068  23000.000000
# 3   3.0  1.0  45.000000  20000.000000
# 4   2.0  0.0  23.000000  15000.000000
# 5   4.0  0.0  12.000000  23000.000000
# 6   0.0  1.0  45.000000  20000.000000
# 7   3.0  0.0  34.909261  18000.000000
# 8   4.0  0.0  12.000000  23000.000000
# 9   0.0  1.0  45.000000  20199.814293
# 10  1.0  1.0  46.000000  15000.000000
# 11  4.0  0.0  31.049068  23000.000000
# 12  5.0  0.0  32.000000  22000.000000
# 13  4.0  0.0  32.000000  22000.000000
# 14  5.0  0.0  32.000000  22000.000000
# 15  4.0  0.0  45.000000  22000.000000

# %%
dfIter["Yas"] = sonuc[2]
dfIter["Gelir"] = sonuc[3]
dfIter.drop(["EnUlke","EnCinsiyet"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 dfIter["Yas"] = sonuc[2]
#       2 dfIter["Gelir"] = sonuc[3]
# ----> 3 dfIter.drop(["EnUlke","EnCinsiyet"],axis=1,inplace=True)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['EnUlke', 'EnCinsiyet'] not found in axis"
