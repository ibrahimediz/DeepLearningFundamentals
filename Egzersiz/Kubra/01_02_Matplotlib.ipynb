# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/workspace/DeepLearningFundamentals/Datasets/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["Age"].hist()
# Out:
# <Axes: >

# %%
df["Age"].hist(bins=20);

# %%
pregnancies_groupby = df.groupby("Pregnancies")["Age"].mean()
pregnancies_groupby
# Out:
# Pregnancies
# 0     27.603604
# 1     27.370370
# 2     27.194175
# 3     29.026667
# 4     32.779412
# 5     39.035088
# 6     39.549020
# 7     41.111111
# 8     45.368421
# 9     44.178571
# 10    42.666667
# 11    44.545455
# 12    47.444444
# 13    44.500000
# 14    42.000000
# 15    43.000000
# 17    47.000000
# Name: Age, dtype: float64

# %%
pregnancies_groupby.plot(kind="bar",title="Hamileliğe göre yaş ortalamaları");

# %%
adres = "/workspace/DeepLearningFundamentals/beginner_datasets/germany.csv"
dfOrnek = pd.read_csv(adres)
dfOrnek.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#        InvoiceDate  UnitPrice  CustomerID  Country
# 0  12/1/2010 13:04       2.95       12662  Germany
# 1  12/1/2010 13:04       2.55       12662  Germany
# 2  12/1/2010 13:04       0.85       12662  Germany
# 3  12/1/2010 13:04       1.65       12662  Germany
# 4  12/1/2010 13:04       1.95       12662  Germany

# %%
dfOrnek.plot(x="InvoiceDate",y="UnitPrice",kind="line");

# %%
x = [1,2,3,4]
plt.plot(x);

# %%
x = [1,2,3,4]
y = [10,20,30,40]
plt.plot(x,y);

# %%
fig,ax = plt.subplots()
ax.plot(x,y);

# %%
fig.savefig("ornekgrafik.png")

# %%
import seaborn as sns
sns.displot(x=df["Age"],kde=True);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspace/DeepLearningFundamentals/env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /workspace/DeepLearningFundamentals/env/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /workspace/DeepLearningFundamentals/env/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# ...

# %%
sns.pairplot(data=df,hue="Outcome")

# %%
df=pd.read_csv("/workspace/DeepLearningFundamentals/beginner_datasets/heart.csv")
df.head()
# Out:
#    AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0      42      1     110      65     64    147      291    2          8
# 1      53      1     130      72     69    167      278    1          6
# 2      53      2     120      90     70    222      342    4          8
# 3      48      4     120      80     72    229      239    4          8
# 4      53      3     118      74     66    134      243    3          8
#
#    MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# 0      4     120      78      271    146       2      1
# 1      2     122      68      250    165       9      1
# 2      1     132      90      304    223       2      1
# 3      2     118      68      209    227       3      1
# 4      5     118      56      261    138       2      1

# %%
import seaborn as sns
sns.pairplot(data=df[["AGE_50","MD_50","CHOL_50","CHOL_62","DEATH"]],hue="DEATH")
